# %% [markdown]
# # Import

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from MyKMeans import KMeans

# %% [markdown]
# # Abathur

# %%
img = Image.open('abathur.jpg')
my_model = KMeans(img, k=10)
my_model.imshow()
# Out:
# Shape : (636, 1000, 3)

# %%
my_model.img_reduction()
# Out:
# Original Shape : (636, 1000, 3)
# Reducted Shape : (159, 250, 3)
# Shape : (636, 1000, 3)
# Shape : (159, 250, 3)

# %%
my_model.fit()
# Out:
# err : 321.7786867210762, iter : 1/10
# err : 108.92867393052671, iter : 2/10
# err : 70.11432377435993, iter : 3/10
# err : 57.40953572165923, iter : 4/10
# err : 46.17683751246671, iter : 5/10
# err : 46.22743679699262, iter : 6/10
# err : 39.6875087885789, iter : 7/10
# err : 39.550812188983265, iter : 8/10
# err : 36.93722213118971, iter : 9/10
# err : 34.106004026309236, iter : 10/10

# %%
my_model.show_result()

# %% [markdown]
# # Nova

# %%
img = Image.open('nova.jpg')
my_model_16 = KMeans(img, k=16)
my_model_16.imshow()
# Out:
# Shape : (168, 300, 3)

# %%
my_model_16.fit()
# Out:
# err : 226.71392077135147, iter : 1/10
# err : 86.307692302443, iter : 2/10
# err : 73.79748831933361, iter : 3/10
# err : 64.14641945001794, iter : 4/10
# err : 49.590318650073286, iter : 5/10
# err : 42.079050873195186, iter : 6/10
# err : 36.241162091941575, iter : 7/10
# err : 28.997525895521495, iter : 8/10
# err : 23.13081438402567, iter : 9/10
# err : 18.841386147137424, iter : 10/10

# %%
my_model_16.show_result()
